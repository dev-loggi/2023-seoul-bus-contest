# %% [markdown]
# # 서울시 이동인구 분석

# %%
# # 폰트 설치
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# # 실행 후 런타임 재시작

# %%
# !pip install geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 15.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.1/16.1 MB 62.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 92.4 MB/s eta 0:00:00
# ...

# %%
# !pip install folium
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import os, shutil
from glob import glob
from zipfile import ZipFile

import numpy as np
import pandas as pd
import geopandas as gpd
import folium

import matplotlib.pyplot as plt
import seaborn as sns

plt.rc('font', family='NanumBarunGothic')
# sns.set(font="Malgun Gothic", #"NanumGothicCoding",
#         rc={"axes.unicode_minus":False}, # 마이너스 부호 깨짐 현상 해결
#         style='darkgrid')

import warnings
warnings.filterwarnings(action='ignore')

from google.colab.data_table import DataTable
DataTable.max_columns = 50

# %%
def read_file(path):
    gdf = gpd.read_file(path, encoding='cp949')
    display(df.head())
    print('shape:', df.shape)
    return gdf

def read_csv(path):
    df = pd.read_csv(path, encoding='cp949')
    display(df.head())
    print('shape:', df.shape)
    return df

def read_excel(path):
    df = pd.read_excel(path)
    display(df.head())
    print('shape:', df.shape)
    return df

# %% [markdown]
# # 1.Gdrive -> Colab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Colab 으로 데이터셋 복사
shutil.copytree('/content/drive/MyDrive/서울시내버스공모전/데이터분석/data/서울생활이동/행정동별', '/content/zips/행정동')
shutil.copytree('/content/drive/MyDrive/서울시내버스공모전/데이터분석/data/서울생활이동/master', '/content/data/master')

# 압축 해제
for file in glob('/content/zips/행정동/*'):
    ZipFile(file).extractall('/content/data/행정동')
# Out:
# 'data/master'

# %% [markdown]
# # 2.데이터 불러오기

# %% [markdown]
# ## 1) master

# %%
sig_geo_master = gpd.read_file('data/master/move-sig-geo-master.shp')
sig_geo_master.crs = 'EPSG:5179'

# %%
emd_geo_master = gpd.read_file('data/master/서울_행정동.shp')

# %%
sig_master = read_excel('data/master/서울생활이동데이터_자치구코드_20210907.xlsx')
# Out:
#       시도    시군구 name  full name
# 0  11000  11010  종로구  서울특별시 종로구
# 1  11000  11020   중구   서울특별시 중구
# 2  11000  11030  용산구  서울특별시 용산구
# 3  11000  11040  성동구  서울특별시 성동구
# 4  11000  11050  광진구  서울특별시 광진구
# shape: (91, 4)

# %%
emd_master = read_excel('data/master/서울생활이동데이터_행정동코드_20210907.xlsx')
# Out:
#       시도    시군구      읍면동 name      full_name
# 0  11000  11010  1101053  사직동  서울특별시 종로구 사직동
# 1  11000  11010  1101054  삼청동  서울특별시 종로구 삼청동
# 2  11000  11010  1101055  부암동  서울특별시 종로구 부암동
# 3  11000  11010  1101056  평창동  서울특별시 종로구 평창동
# 4  11000  11010  1101057  무악동  서울특별시 종로구 무악동
# shape: (1152, 5)

# %% [markdown]
# ## 2) 행정동별 이동인구 데이터

# %%
paths = glob('data/행정동/*')

# %%
move = read_csv(paths[0])
# Out:
#      대상연월 요일  도착시간  출발 행정동 코드  도착 행정동 코드 성별  나이 이동유형  평균 이동 시간(분) 이동인구(합)
# 0  202201  일    14    1101053    1101053  F   0   WW           10   27.52
# 1  202201  일    14    1101053    1101053  F  10   EE           10   11.98
# 2  202201  일    14    1101053    1101053  F  15   EH           10    4.04
# 3  202201  일    14    1101053    1101053  F  15   HE           10    4.04
# 4  202201  일    14    1101053    1101053  F  15   EE           10   28.23
# shape: (7424223, 10)
